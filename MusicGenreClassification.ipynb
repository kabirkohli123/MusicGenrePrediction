# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('MusicGenreTrain.csv')
df
# Out:
#                  Artist Name                             Track Name  \
# 0                 Bruno Mars  That's What I Like (feat. Gucci Mane)
# 1                     Boston                           Hitch a Ride
# 2              The Raincoats                     No Side to Fall In
# 3                       Deno             Lingo (feat. J.I & Chunkz)
# 4      Red Hot Chili Peppers      Nobody Weird Like Me - Remastered
# ...                      ...                                    ...
# 17991            Green-House                              Find Home
# 17992               Micatone                               All Gone
# 17993        Smash Hit Combo                           Peine perdue
# 17994                Beherit                         Salomon's Gate
# 17995         The Raconteurs                     Broken Boy Soldier
#
#        Popularity  danceability  energy   key  loudness  mode  speechiness  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17996 entries, 0 to 17995
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Artist Name         17996 non-null  object
#  1   Track Name          17996 non-null  object
#  2   Popularity          17568 non-null  float64
#  3   danceability        17996 non-null  float64
#  4   energy              17996 non-null  float64
#  5   key                 15982 non-null  float64
#  6   loudness            17996 non-null  float64
#  7   mode                17996 non-null  int64
#  8   speechiness         17996 non-null  float64
#  9   acousticness        17996 non-null  float64
#  10  instrumentalness    13619 non-null  float64
#  11  liveness            17996 non-null  float64
#  12  valence             17996 non-null  float64
#  13  tempo               17996 non-null  float64
#  14  duration_in min/ms  17996 non-null  float64
# ...

# %%
df.describe()
# Out:
#          Popularity  danceability        energy           key      loudness  \
# count  17568.000000  17996.000000  17996.000000  15982.000000  17996.000000
# mean      44.512124      0.543433      0.662777      5.952447     -7.910660
# std       17.426928      0.166268      0.235373      3.196854      4.049151
# min        1.000000      0.059600      0.000020      1.000000    -39.952000
# 25%       33.000000      0.432000      0.509000      3.000000     -9.538000
# 50%       44.000000      0.545000      0.700000      6.000000     -7.016000
# 75%       56.000000      0.659000      0.860000      9.000000     -5.189000
# max      100.000000      0.989000      1.000000     11.000000      1.355000
#
#                mode   speechiness  acousticness  instrumentalness  \
# count  17996.000000  17996.000000  17996.000000      13619.000000
# mean       0.636753      0.079707      0.247082          0.177562
# std        0.480949      0.083576      0.310632          0.304048
# ...

# %%
df.shape
# Out:
# (17996, 17)

# %%
df['Artist Name'].unique()
# Out:
# array(['Bruno Mars', 'Boston', 'The Raincoats', ..., 'Micatone',
#        'Smash Hit Combo', 'Beherit'], dtype=object)

# %%
len(df['Artist Name'].unique())
# Out:
# 9149

# %%
df['Track Name'].unique()
# Out:
# array(["That's What I Like (feat. Gucci Mane)", 'Hitch a Ride',
#        'No Side to Fall In', ..., 'Peine perdue', "Salomon's Gate",
#        'Broken Boy Soldier'], dtype=object)

# %%
len(df['Track Name'].unique())
# Out:
# 15129

# %%
for i in range(17):
    nullCheck = df.iloc[:,i].isnull().sum()
    print("The number of null value in column ",i+1," are: ",nullCheck)
# Out:
# The number of null value in column  1  are:  0
# The number of null value in column  2  are:  0
# The number of null value in column  3  are:  428
# The number of null value in column  4  are:  0
# The number of null value in column  5  are:  0
# The number of null value in column  6  are:  2014
# The number of null value in column  7  are:  0
# The number of null value in column  8  are:  0
# The number of null value in column  9  are:  0
# The number of null value in column  10  are:  0
# The number of null value in column  11  are:  4377
# The number of null value in column  12  are:  0
# The number of null value in column  13  are:  0
# The number of null value in column  14  are:  0
# The number of null value in column  15  are:  0
# The number of null value in column  16  are:  0
# The number of null value in column  17  are:  0

# %%
df.isnull().sum()
# Out:
# Artist Name              0
# Track Name               0
# Popularity             428
# danceability             0
# energy                   0
# key                   2014
# loudness                 0
# mode                     0
# speechiness              0
# acousticness             0
# instrumentalness      4377
# liveness                 0
# valence                  0
# tempo                    0
# duration_in min/ms       0
# time_signature           0
# Class                    0
# dtype: int64

# %%
#Colums having null values
#popularity
#Key
#Instrumentalness

# %%
nullPercentage = pd.DataFrame(df.isnull().sum(),columns=['Number of Null Values'])
nullPercentage['Fraction of Null Values'] = np.round((df.isnull().sum()/df.shape[0]),2)
nullPercentage
# Out:
#                     Number of Null Values  Fraction of Null Values
# Artist Name                             0                     0.00
# Track Name                              0                     0.00
# Popularity                            428                     0.02
# danceability                            0                     0.00
# energy                                  0                     0.00
# key                                  2014                     0.11
# loudness                                0                     0.00
# mode                                    0                     0.00
# speechiness                             0                     0.00
# acousticness                            0                     0.00
# instrumentalness                     4377                     0.24
# liveness                                0                     0.00
# valence                                 0                     0.00
# ...

# %%
nullPercentage = pd.DataFrame(df.isnull().sum(),columns=['Number of Null Values'])
nullPercentage['Fraction of Null Values'] = np.round((df.isnull().sum()/df.shape[0]),2)*100
nullPercentage
# Out:
#                     Number of Null Values  Fraction of Null Values
# Artist Name                             0                      0.0
# Track Name                              0                      0.0
# Popularity                            428                      2.0
# danceability                            0                      0.0
# energy                                  0                      0.0
# key                                  2014                     11.0
# loudness                                0                      0.0
# mode                                    0                      0.0
# speechiness                             0                      0.0
# acousticness                            0                      0.0
# instrumentalness                     4377                     24.0
# liveness                                0                      0.0
# valence                                 0                      0.0
# ...

# %%
nullPercentage = nullPercentage.sort_values(['Number of Null Values'],ascending=False)
nullPercentage
# Out:
#                     Number of Null Values  Fraction of Null Values
# instrumentalness                     4377                     24.0
# key                                  2014                     11.0
# Popularity                            428                      2.0
# Artist Name                             0                      0.0
# time_signature                          0                      0.0
# duration_in min/ms                      0                      0.0
# tempo                                   0                      0.0
# valence                                 0                      0.0
# liveness                                0                      0.0
# speechiness                             0                      0.0
# acousticness                            0                      0.0
# Track Name                              0                      0.0
# mode                                    0                      0.0
# ...

# %%
df[df['Popularity'].isnull()]
# Out:
#                                              Artist Name  \
# 25     IndianRaga, Akshay Anantapadmanabhan, Madhu Iy...
# 43                              Lilly Wood and The Prick
# 51                                             How Lucky
# 95                                           The Beatles
# 111                                        Faith No More
# ...                                                  ...
# 17741                                           Westlife
# 17855                                             Avarus
# 17873                                    Erika de Casier
# 17912                                        Hype Lights
# 17931                                           Westlife
#
#                               Track Name  Popularity  danceability  energy  \
# 25     Swagatham Krishna - Mohanam - Adi         NaN         0.548   0.711
# 43                                A Song         NaN         0.618   0.438
# ...

# %%
nullPopularity = df[df['Popularity'].isnull()]
nullPopularity.index
# Out:
# Index([   25,    43,    51,    95,   111,   116,   268,   284,   318,   335,
#        ...
#        17626, 17635, 17689, 17712, 17726, 17741, 17855, 17873, 17912, 17931],
#       dtype='int64', length=428)

# %%
df = df.drop(nullPopularity.index)
df
# Out:
#                  Artist Name                             Track Name  \
# 0                 Bruno Mars  That's What I Like (feat. Gucci Mane)
# 1                     Boston                           Hitch a Ride
# 2              The Raincoats                     No Side to Fall In
# 3                       Deno             Lingo (feat. J.I & Chunkz)
# 4      Red Hot Chili Peppers      Nobody Weird Like Me - Remastered
# ...                      ...                                    ...
# 17991            Green-House                              Find Home
# 17992               Micatone                               All Gone
# 17993        Smash Hit Combo                           Peine perdue
# 17994                Beherit                         Salomon's Gate
# 17995         The Raconteurs                     Broken Boy Soldier
#
#        Popularity  danceability  energy   key  loudness  mode  speechiness  \
# ...

# %%
df.shape
# Out:
# (17568, 17)

# %%
nullPercentage = pd.DataFrame(df.isnull().sum(),columns=['Number of Null Values'])
nullPercentage['Fraction of Null Values'] = np.round((df.isnull().sum()/df.shape[0]),2)*100
nullPercentage = nullPercentage.sort_values(['Number of Null Values'],ascending=False)
nullPercentage
# Out:
#                     Number of Null Values  Fraction of Null Values
# instrumentalness                     4262                     24.0
# key                                  1955                     11.0
# Artist Name                             0                      0.0
# acousticness                            0                      0.0
# time_signature                          0                      0.0
# duration_in min/ms                      0                      0.0
# tempo                                   0                      0.0
# valence                                 0                      0.0
# liveness                                0                      0.0
# speechiness                             0                      0.0
# Track Name                              0                      0.0
# mode                                    0                      0.0
# loudness                                0                      0.0
# ...

# %%
nullKey = df[df['key'].isnull()]
nullKey
# Out:
#                  Artist Name  \
# 33                    Dreezy
# 34         The Ayoub Sisters
# 36               Moon Guitar
# 41               Lior Narkis
# 47                 The Clash
# ...                      ...
# 17967             Dudu Tassa
# 17970               Dua Lipa
# 17982  Lucia & The Best Boys
# 17985         Hippie Hourrah
# 17987            Jilted John
#
#                                              Track Name  Popularity  \
# 33                                       Where Them $ @        42.0
# 34                                       Mother's Pride        16.0
# 36                                               Struna        47.0
# 41     ◊ó◊ú◊ß◊™ ◊ê◊ú◊ï◊î◊ô◊ù - ◊î◊©◊ô◊® ◊©◊ú ◊ê◊ï◊§◊ô◊®        44.0
# 47                   The Magnificent Seven - Remastered        56.0
# ...                                                 ...         ...
# 17967                                          ◊î◊ß◊ô◊®        23.0
# ...

# %%
nullKey.index
# Out:
# Index([   33,    34,    36,    41,    47,    52,    59,    66,    69,    75,
#        ...
#        17934, 17945, 17957, 17961, 17962, 17967, 17970, 17982, 17985, 17987],
#       dtype='int64', length=1955)

# %%
df = df.drop(nullKey.index)
df
# Out:
#                  Artist Name                             Track Name  \
# 0                 Bruno Mars  That's What I Like (feat. Gucci Mane)
# 1                     Boston                           Hitch a Ride
# 2              The Raincoats                     No Side to Fall In
# 3                       Deno             Lingo (feat. J.I & Chunkz)
# 4      Red Hot Chili Peppers      Nobody Weird Like Me - Remastered
# ...                      ...                                    ...
# 17991            Green-House                              Find Home
# 17992               Micatone                               All Gone
# 17993        Smash Hit Combo                           Peine perdue
# 17994                Beherit                         Salomon's Gate
# 17995         The Raconteurs                     Broken Boy Soldier
#
#        Popularity  danceability  energy   key  loudness  mode  speechiness  \
# ...

# %%
nullPercentage = pd.DataFrame(df.isnull().sum(),columns=['Number of Null Values'])
nullPercentage['Percentage of Null Values'] = np.round(df.isnull().sum()/df.shape[0],2)*100
nullPercentage = nullPercentage.sort_values(['Number of Null Values'],ascending=False)
nullPercentage
# Out:
#                     Number of Null Values  Percentage of Null Values
# instrumentalness                     3800                       24.0
# Artist Name                             0                        0.0
# acousticness                            0                        0.0
# time_signature                          0                        0.0
# duration_in min/ms                      0                        0.0
# tempo                                   0                        0.0
# valence                                 0                        0.0
# liveness                                0                        0.0
# speechiness                             0                        0.0
# Track Name                              0                        0.0
# mode                                    0                        0.0
# loudness                                0                        0.0
# key                                     0                        0.0
# ...

# %%
avg = np.mean(df['instrumentalness'])
avg
# Out:
# 0.17899141338186744

# %%
df = df.fillna(value=avg)
df
# Out:
#                  Artist Name                             Track Name  \
# 0                 Bruno Mars  That's What I Like (feat. Gucci Mane)
# 1                     Boston                           Hitch a Ride
# 2              The Raincoats                     No Side to Fall In
# 3                       Deno             Lingo (feat. J.I & Chunkz)
# 4      Red Hot Chili Peppers      Nobody Weird Like Me - Remastered
# ...                      ...                                    ...
# 17991            Green-House                              Find Home
# 17992               Micatone                               All Gone
# 17993        Smash Hit Combo                           Peine perdue
# 17994                Beherit                         Salomon's Gate
# 17995         The Raconteurs                     Broken Boy Soldier
#
#        Popularity  danceability  energy   key  loudness  mode  speechiness  \
# ...

# %%
nullPercentage = pd.DataFrame(df.isnull().sum(),columns=['Number of Null Values'])
nullPercentage['Percentage of Null Values'] = np.round(df.isnull().sum()/df.shape[0],2)*100
nullPercentage = nullPercentage.sort_values(['Number of Null Values'],ascending=False)
nullPercentage
# Out:
#                     Number of Null Values  Percentage of Null Values
# Artist Name                             0                        0.0
# acousticness                            0                        0.0
# time_signature                          0                        0.0
# duration_in min/ms                      0                        0.0
# tempo                                   0                        0.0
# valence                                 0                        0.0
# liveness                                0                        0.0
# instrumentalness                        0                        0.0
# speechiness                             0                        0.0
# Track Name                              0                        0.0
# mode                                    0                        0.0
# loudness                                0                        0.0
# key                                     0                        0.0
# ...

# %%
artist = df['Artist Name'].unique()
artist
# Out:
# array(['Bruno Mars', 'Boston', 'The Raincoats', ..., 'Micatone',
#        'Smash Hit Combo', 'Beherit'], dtype=object)

# %%
collaborationLambda = lambda x:1 if(len(x.split(','))>1) else 0

# %%
df['Collaboration'] = df['Artist Name'].apply(collaborationLambda)
df['Collaboration']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 17991    0
# 17992    0
# 17993    0
# 17994    0
# 17995    0
# Name: Collaboration, Length: 15613, dtype: int64

# %%
df
# Out:
#                  Artist Name                             Track Name  \
# 0                 Bruno Mars  That's What I Like (feat. Gucci Mane)
# 1                     Boston                           Hitch a Ride
# 2              The Raincoats                     No Side to Fall In
# 3                       Deno             Lingo (feat. J.I & Chunkz)
# 4      Red Hot Chili Peppers      Nobody Weird Like Me - Remastered
# ...                      ...                                    ...
# 17991            Green-House                              Find Home
# 17992               Micatone                               All Gone
# 17993        Smash Hit Combo                           Peine perdue
# 17994                Beherit                         Salomon's Gate
# 17995         The Raconteurs                     Broken Boy Soldier
#
#        Popularity  danceability  energy   key  loudness  mode  speechiness  \
# ...

# %%
sns.set()

# %%
plt.figure(figsize=(20,15))
correlation_matrix = df.corr(numeric_only=True)
sns.heatmap(correlation_matrix,annot=True,cmap='Purples',fmt='0.1f')
plt.show()

# %%
sns.kdeplot(df['Popularity'])
# Out:
# <Axes: xlabel='Popularity', ylabel='Density'>

# %%
sns.kdeplot(df['danceability'])
# Out:
# <Axes: xlabel='danceability', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['Artist Name', 'Track Name', 'Popularity', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_in min/ms', 'time_signature', 'Class', 'Collaboration'],
#       dtype='object')

# %%
sns.kdeplot(df['energy'])
# Out:
# <Axes: xlabel='energy', ylabel='Density'>

# %%
sns.kdeplot(df['loudness'])
# Out:
# <Axes: xlabel='loudness', ylabel='Density'>

# %%
df['mode'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.columns
# Out:
# Index(['Artist Name', 'Track Name', 'Popularity', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_in min/ms', 'time_signature', 'Class', 'Collaboration'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 18

# %%
for i in range(2,len(df.columns)):
    sns.kdeplot(df.iloc[:,i]) 
    plt.show()

# %%
count1 = df[df['mode']==1]
count1 = count1.shape[0]

count0 = df[df['mode']==0]
count0 = count0.shape[0]

plt.pie([count0,count1],labels=['Mode 0','Mode 1'],autopct='%1.1f%%')
plt.show()

# %%
df['Class'].unique()
# Out:
# array([ 5, 10,  6,  2,  4,  8,  9,  3,  7,  1,  0], dtype=int64)

# %%
count0 = df[df['Class']==0]
count0 = count0.shape[0]

count1 = df[df['Class']==1]
count1 = count1.shape[0]

count2 = df[df['Class']==2]
count2 = count2.shape[0]

count3 = df[df['Class']==3]
count3 = count3.shape[0]

count4 = df[df['Class']==4]
count4 = count4.shape[0]

count5 = df[df['Class']==5]
count5 = count5.shape[0]

count6 = df[df['Class']==6]
count6 = count6.shape[0]

count7 = df[df['Class']==7]
count7 = count7.shape[0]

count8 = df[df['Class']==8]
count8 = count8.shape[0]

count9 = df[df['Class']==9]
count9 = count9.shape[0]

count10 = df[df['Class']==10]
count10 = count10.shape[0]

# %%
plt.figure(figsize=(15,15))
plt.pie([count0,count1,count2,count3,count4,count5,count6,count7,count8,count9,count10],labels=['Class 0','Class 1','Class 2','Class 3','Class 4','Class 5','Class 6','Class 7','Class 8','Class 9','Class 10'],autopct='%1.1f%%')
plt.show()

# %%
top5 = df.sort_values(by = ['Popularity'],ascending=False)
top5.head(5)
# Out:
#                         Artist Name                      Track Name  \
# 13489                      Måneskin                         Beggin'
# 11781                     Lil Nas X  MONTERO (Call Me By Your Name)
# 187                  Olivia Rodrigo                        good 4 u
# 953                        Doja Cat        Kiss Me More (feat. SZA)
# 14830  The Kid LAROI, Justin Bieber       STAY (with Justin Bieber)
#
#        Popularity  danceability  energy   key  loudness  mode  speechiness  \
# 13489       100.0         0.714   0.800  11.0    -4.808     0       0.0504
# 11781       100.0         0.610   0.508   8.0    -6.682     0       0.1520
# 187          99.0         0.563   0.664   9.0    -5.044     1       0.1540
# 953          98.0         0.762   0.701   8.0    -3.541     1       0.0286
# 14830        97.0         0.591   0.764   1.0    -5.484     1       0.0483
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
top5 = top5[0:5]
top5
# Out:
#                         Artist Name                      Track Name  \
# 13489                      Måneskin                         Beggin'
# 11781                     Lil Nas X  MONTERO (Call Me By Your Name)
# 187                  Olivia Rodrigo                        good 4 u
# 953                        Doja Cat        Kiss Me More (feat. SZA)
# 14830  The Kid LAROI, Justin Bieber       STAY (with Justin Bieber)
#
#        Popularity  danceability  energy   key  loudness  mode  speechiness  \
# 13489       100.0         0.714   0.800  11.0    -4.808     0       0.0504
# 11781       100.0         0.610   0.508   8.0    -6.682     0       0.1520
# 187          99.0         0.563   0.664   9.0    -5.044     1       0.1540
# 953          98.0         0.762   0.701   8.0    -3.541     1       0.0286
# 14830        97.0         0.591   0.764   1.0    -5.484     1       0.0483
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
sns.barplot(x='Track Name', y='Popularity', data=top5)
plt.xticks(rotation=90)
plt.show()

# %%
plt.plot(top5['Track Name'],top5['Popularity'])
plt.scatter(x='Track Name', y='Popularity', data=top5)
plt.xticks(rotation=90)
plt.show()

# %%
top5longest = df.sort_values(by=['duration_in min/ms'],ascending=False)
top5longest = top5longest[0:5]

# %%
sns.barplot(x=top5longest['Track Name'],y=top5longest['duration_in min/ms'])
plt.xticks(rotation=90)
plt.show()

# %%
df.columns
# Out:
# Index(['Artist Name', 'Track Name', 'Popularity', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_in min/ms', 'time_signature', 'Class', 'Collaboration'],
#       dtype='object')

# %%
df = df.reset_index(drop=True)
df
# Out:
#                  Artist Name                             Track Name  \
# 0                 Bruno Mars  That's What I Like (feat. Gucci Mane)
# 1                     Boston                           Hitch a Ride
# 2              The Raincoats                     No Side to Fall In
# 3                       Deno             Lingo (feat. J.I & Chunkz)
# 4      Red Hot Chili Peppers      Nobody Weird Like Me - Remastered
# ...                      ...                                    ...
# 15608            Green-House                              Find Home
# 15609               Micatone                               All Gone
# 15610        Smash Hit Combo                           Peine perdue
# 15611                Beherit                         Salomon's Gate
# 15612         The Raconteurs                     Broken Boy Soldier
#
#        Popularity  danceability  energy   key  loudness  mode  speechiness  \
# ...

# %%
df.columns
# Out:
# Index(['Artist Name', 'Track Name', 'Popularity', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_in min/ms', 'time_signature', 'Class', 'Collaboration'],
#       dtype='object')

# %%
df2 = df.drop(['Artist Name','Track Name','mode','time_signature','Class','Collaboration'],axis='columns')
df2
# Out:
#        Popularity  danceability  energy   key  loudness  speechiness  \
# 0            60.0         0.854   0.564   1.0    -4.964       0.0485
# 1            54.0         0.382   0.814   3.0    -7.230       0.0406
# 2            35.0         0.434   0.614   6.0    -8.334       0.0525
# 3            66.0         0.853   0.597  10.0    -6.528       0.0555
# 4            53.0         0.167   0.975   2.0    -4.279       0.2160
# ...           ...           ...     ...   ...       ...          ...
# 15608        35.0         0.166   0.109   7.0   -17.100       0.0413
# 15609        27.0         0.638   0.223  11.0   -10.174       0.0329
# 15610        34.0         0.558   0.981   4.0    -4.683       0.0712
# 15611        29.0         0.215   0.805   6.0   -12.757       0.1340
# 15612        43.0         0.400   0.853   4.0    -5.320       0.0591
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.017100          0.178991    0.0849   0.8990  134.071
# ...

# %%
def normalize(feature):
    feature = (feature - np.mean(feature))/np.std(feature)
    return feature

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
df2 = scaler.fit_transform(df2)
df2
# Out:
# array([[ 0.89219173,  1.86237823, -0.441135  , ...,  1.7256498 ,
#          0.38710811,  0.28217801],
#        [ 0.54633771, -0.97147431,  0.62995225, ...,  0.34911506,
#         -0.20958453,  0.43689226],
#        [-0.54886669, -0.65927021, -0.22691755, ...,  1.25846225,
#          0.84808256, -0.84569128],
#        ...,
#        [-0.60650903,  0.08521647,  1.34543854, ..., -0.93147938,
#         -0.59753467,  0.11629603],
#        [-0.89472071, -1.97412976,  0.59139311, ..., -0.54354686,
#          0.29538741,  0.1476325 ],
#        [-0.087728  , -0.86340366,  0.79704187, ..., -0.45177788,
#          0.52363919, -0.19061363]])

# %%
df.columns
# Out:
# Index(['Artist Name', 'Track Name', 'Popularity', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_in min/ms', 'time_signature', 'Class', 'Collaboration'],
#       dtype='object')

# %%
df2 = pd.DataFrame(df2,columns=['Popularity', 'danceability', 'energy',
       'key', 'loudness', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo',
       'duration_in min/ms'])
df2
# Out:
#        Popularity  danceability    energy       key  loudness  speechiness  \
# 0        0.892192      1.862378 -0.441135 -1.551717  0.727199    -0.385493
# 1        0.546338     -0.971474  0.629952 -0.925698  0.158830    -0.478702
# 2       -0.548867     -0.659270 -0.226918  0.013332 -0.118080    -0.338298
# 3        1.238046      1.856374 -0.299751  1.265371  0.334909    -0.302902
# 4        0.488695     -2.262318  1.319732 -1.238708  0.899014     1.590773
# ...           ...           ...       ...       ...       ...          ...
# 15608   -0.548867     -2.268322 -2.390514  0.326342 -2.316809    -0.470443
# 15609   -1.010005      0.565530 -1.902098  1.578381 -0.579597    -0.569551
# 15610   -0.606509      0.085216  1.345439 -0.612688  0.797680    -0.117664
# 15611   -0.894721     -1.974130  0.591393  0.013332 -1.227477     0.623288
# 15612   -0.087728     -0.863404  0.797042 -0.612688  0.637905    -0.260427
#
# ...

# %%
sns.kdeplot(df2['key'])
# Out:
# <Axes: xlabel='key', ylabel='Density'>

# %%
df = df.drop(['Popularity', 'danceability', 'energy',
       'key', 'loudness', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo',
       'duration_in min/ms'],axis='columns')
df
# Out:
#                  Artist Name                             Track Name  mode  \
# 0                 Bruno Mars  That's What I Like (feat. Gucci Mane)     1
# 1                     Boston                           Hitch a Ride     1
# 2              The Raincoats                     No Side to Fall In     1
# 3                       Deno             Lingo (feat. J.I & Chunkz)     0
# 4      Red Hot Chili Peppers      Nobody Weird Like Me - Remastered     1
# ...                      ...                                    ...   ...
# 15608            Green-House                              Find Home     0
# 15609               Micatone                               All Gone     0
# 15610        Smash Hit Combo                           Peine perdue     0
# 15611                Beherit                         Salomon's Gate     0
# 15612         The Raconteurs                     Broken Boy Soldier     0
#
#        time_signature  Class  Collaboration
# ...

# %%
df2
# Out:
#        Popularity  danceability    energy       key  loudness  speechiness  \
# 0        0.892192      1.862378 -0.441135 -1.551717  0.727199    -0.385493
# 1        0.546338     -0.971474  0.629952 -0.925698  0.158830    -0.478702
# 2       -0.548867     -0.659270 -0.226918  0.013332 -0.118080    -0.338298
# 3        1.238046      1.856374 -0.299751  1.265371  0.334909    -0.302902
# 4        0.488695     -2.262318  1.319732 -1.238708  0.899014     1.590773
# ...           ...           ...       ...       ...       ...          ...
# 15608   -0.548867     -2.268322 -2.390514  0.326342 -2.316809    -0.470443
# 15609   -1.010005      0.565530 -1.902098  1.578381 -0.579597    -0.569551
# 15610   -0.606509      0.085216  1.345439 -0.612688  0.797680    -0.117664
# 15611   -0.894721     -1.974130  0.591393  0.013332 -1.227477     0.623288
# 15612   -0.087728     -0.863404  0.797042 -0.612688  0.637905    -0.260427
#
# ...

# %%
df = pd.concat([df,df2],axis='columns')
df
# Out:
#                  Artist Name                             Track Name  mode  \
# 0                 Bruno Mars  That's What I Like (feat. Gucci Mane)     1
# 1                     Boston                           Hitch a Ride     1
# 2              The Raincoats                     No Side to Fall In     1
# 3                       Deno             Lingo (feat. J.I & Chunkz)     0
# 4      Red Hot Chili Peppers      Nobody Weird Like Me - Remastered     1
# ...                      ...                                    ...   ...
# 15608            Green-House                              Find Home     0
# 15609               Micatone                               All Gone     0
# 15610        Smash Hit Combo                           Peine perdue     0
# 15611                Beherit                         Salomon's Gate     0
# 15612         The Raconteurs                     Broken Boy Soldier     0
#
#        time_signature  Class  Collaboration  Popularity  danceability  \
# ...

# %%
df['Artist Name'].unique()
# Out:
# array(['Bruno Mars', 'Boston', 'The Raincoats', ..., 'Micatone',
#        'Smash Hit Combo', 'Beherit'], dtype=object)

# %%
len(df['Artist Name'].unique())
# Out:
# 8264

# %%
df = df.drop(['Artist Name','Track Name'],axis='columns')
df
# Out:
#        mode  time_signature  Class  Collaboration  Popularity  danceability  \
# 0         1               4      5              0    0.892192      1.862378
# 1         1               4     10              0    0.546338     -0.971474
# 2         1               4      6              0   -0.548867     -0.659270
# 3         0               4      5              0    1.238046      1.856374
# 4         1               4     10              0    0.488695     -2.262318
# ...     ...             ...    ...            ...         ...           ...
# 15608     0               3      6              0   -0.548867     -2.268322
# 15609     0               4      2              0   -1.010005      0.565530
# 15610     0               4      8              0   -0.606509      0.085216
# 15611     0               4      8              0   -0.894721     -1.974130
# 15612     0               4     10              0   -0.087728     -0.863404
#
# ...

# %%
Y = df['Class']

# %%
X = df.drop(['Class'],axis='columns')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,train_size=0.8,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_predict = lr.predict(X_test)
print("The first 10 predicted values of Y is:")
print(Y_predict[:10])
print("The first 10 test values of Y is:")
print(np.array(Y_test[:10]))
print("The accuracy of Linear Regression is:")
print(lr.score(X_test,Y_test))
from sklearn.model_selection import cross_val_score

print("The Cross val score of Linear Regression is:")
print(cross_val_score(lr,X,Y,cv=10))
# Out:
# The first 10 predicted values of Y is:
# [8.78262641 8.74443939 6.01100202 5.57553725 6.99262981 7.90871328
#  6.19167016 6.99428209 8.26383099 8.03531035]
# The first 10 test values of Y is:
# [ 6  8 10  1  9 10  5  5  8  8]
# The accuracy of Linear Regression is:
# 0.11232919305562306
# The Cross val score of Linear Regression is:
# [0.15459944 0.1250539  0.11892952 0.11394122 0.11936038 0.13771774
#  0.11163385 0.11169902 0.09049476 0.12236722]

# %%
from sklearn.linear_model import LogisticRegression
lrr = LogisticRegression(multi_class='multinomial')
lrr.fit(X_train,Y_train)
# Out:
# LogisticRegression(multi_class='multinomial')

# %%
Y_predict = lrr.predict(X_test)
print("The first 10 predicted values of Y is:")
print(Y_predict[:10])
print("The first 10 test values of Y is:")
print(np.array(Y_test[:10]))
print("The accuracy of Logistic Regression is:")
print(lrr.score(X_test,Y_test))
print("The Cross val score of Logistic Regression is:")
print(cross_val_score(lrr,X,Y,cv=10))
# Out:
# The first 10 predicted values of Y is:
# [ 8  8  6 10  9  8  5  5 10 10]
# The first 10 test values of Y is:
# [ 6  8 10  1  9 10  5  5  8  8]
# The accuracy of Logistic Regression is:
# 0.48286903618315724
# The Cross val score of Logistic Regression is:
# [0.5128041  0.50384123 0.48591549 0.49711723 0.50224215 0.50160154
#  0.46764894 0.49391416 0.48878924 0.49647662]

# %%
from sklearn.linear_model import Lasso
lasso = Lasso()
lasso.fit(X_train,Y_train)
# Out:
# Lasso()

# %%
Y_predict = lasso.predict(X_test)
print("The first 10 predicted values of Y is:")
print(Y_predict[:10])
print("The first 10 test values of Y is:")
print(np.array(Y_test[:10]))
print("The accuracy of Lasso Regression is:")
print(lasso.score(X_test,Y_test))
print("The Cross val score of Lasso Regression is:")
print(cross_val_score(lasso,X,Y,cv=10))
# Out:
# The first 10 predicted values of Y is:
# [6.72802242 6.72802242 6.72802242 6.72802242 6.72802242 6.72802242
#  6.72802242 6.72802242 6.72802242 6.72802242]
# The first 10 test values of Y is:
# [ 6  8 10  1  9 10  5  5  8  8]
# The accuracy of Lasso Regression is:
# -0.00013196566383300024
# The Cross val score of Lasso Regression is:
# [-1.12921742e-04 -4.00895506e-04 -3.72238824e-04 -2.34805317e-05
#  -8.85665048e-04 -1.39170947e-03 -3.28505200e-05 -4.38375915e-04
#  -1.03500978e-03 -2.65182731e-05]

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()
ridge.fit(X_train,Y_train)
# Out:
# Ridge()

# %%
Y_predict = ridge.predict(X_test)
print("The first 10 predicted values of Y is:")
print(Y_predict[:10])
print("The first 10 test values of Y is:")
print(np.array(Y_test[:10]))
print("The accuracy of Ridge Regression is:")
print(ridge.score(X_test,Y_test))
print("The Cross val score of Ridge Regression is:")
print(cross_val_score(ridge,X,Y,cv=10))
# Out:
# The first 10 predicted values of Y is:
# [8.78308329 8.74442249 6.01098969 5.57535567 6.99266439 7.90858754
#  6.19165875 6.99419389 8.26380918 8.03535615]
# The first 10 test values of Y is:
# [ 6  8 10  1  9 10  5  5  8  8]
# The accuracy of Ridge Regression is:
# 0.11232381745321518
# The Cross val score of Ridge Regression is:
# [0.15460081 0.1250645  0.11892817 0.11393758 0.11936158 0.13772398
#  0.11164022 0.1116897  0.09049318 0.12236489]

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train,Y_train)
# Out:
# GaussianNB()

# %%
Y_predict = nb.predict(X_test)
print("The first 10 predicted values of Y is:")
print(Y_predict[:10])
print("The first 10 test values of Y is:")
print(np.array(Y_test[:10]))
print("The accuracy of Naive Bayes is:")
print(nb.score(X_test,Y_test))
print("The Cross val score of Naive Bayes is:")
print(cross_val_score(nb,X,Y,cv=10))
# Out:
# The first 10 predicted values of Y is:
# [10  8  5  5  5  8  5  5  5  5]
# The first 10 test values of Y is:
# [ 6  8 10  1  9 10  5  5  8  8]
# The accuracy of Naive Bayes is:
# 0.2372718539865514
# The Cross val score of Naive Bayes is:
# [0.26504481 0.27144686 0.25480154 0.25560538 0.24919923 0.24023062
#  0.24663677 0.25112108 0.24407431 0.25048046]

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train,Y_train)
# Out:
# SVC()

# %%
Y_predict = svc.predict(X_test)
print("The first 10 predicted values of Y is:")
print(Y_predict[:10])
print("The first 10 test values of Y is:")
print(np.array(Y_test[:10]))
print("The accuracy of Standard Vector Classifier is:")
print(svc.score(X_test,Y_test))
print("The Cross val score of Standard Vector Classifier is:")
print(cross_val_score(svc,X,Y,cv=10))
# Out:
# The first 10 predicted values of Y is:
# [10  8 10 10  9 10  5  5 10 10]
# The first 10 test values of Y is:
# [ 6  8 10  1  9 10  5  5  8  8]
# The accuracy of Standard Vector Classifier is:
# 0.5113672750560359
# The Cross val score of Standard Vector Classifier is:
# [0.53201024 0.53521127 0.52304738 0.53363229 0.51569507 0.53363229
#  0.50032031 0.51505445 0.51121076 0.53171044]

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
Y_predict = rfc.predict(X_test)
print("The first 10 predicted values of Y is:")
print(Y_predict[:10])
print("The first 10 test values of Y is:")
print(np.array(Y_test[:10]))
print("The accuracy of Random Forest Classifier is:")
print(rfc.score(X_test,Y_test))
print("The Cross val score of Random Forest Classifier is:")
print(cross_val_score(rfc,X,Y,cv=10))
# Out:
# The first 10 predicted values of Y is:
# [ 8  8 10  6  9  8  5  5 10 10]
# The first 10 test values of Y is:
# [ 6  8 10  1  9 10  5  5  8  8]
# The accuracy of Random Forest Classifier is:
# 0.4931155939801473
# The Cross val score of Random Forest Classifier is:
# [0.50768246 0.50576184 0.49807939 0.50352338 0.495836   0.50992953
#  0.48942985 0.49391416 0.4830237  0.49775785]

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
Y_predict = knn.predict(X_test)
print("The first 10 predicted values of Y is:")
print(Y_predict[:10])
print("The first 10 test values of Y is:")
print(np.array(Y_test[:10]))
print("The accuracy of KNN is:")
print(knn.score(X_test,Y_test))
print("The Cross val score of KNN is:")
print(cross_val_score(knn,X,Y,cv=10))
# Out:
# The first 10 predicted values of Y is:
# [8 8 1 6 9 6 1 9 8 1]
# The first 10 test values of Y is:
# [ 6  8 10  1  9 10  5  5  8  8]
# The accuracy of KNN is:
# 0.43483829650976624
# The Cross val score of KNN is:
# [0.43982074 0.44430218 0.44494238 0.43497758 0.43754004 0.42472774
#  0.42664958 0.44971172 0.4189622  0.43754004]

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(X_train,Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
Y_predict = xgb.predict(X_test)
print("The first 10 predicted values of Y is:")
print(Y_predict[:10])
print("The first 10 test values of Y is:")
print(np.array(Y_test[:10]))
print("The accuracy of XGB is:")
print(xgb.score(X_test,Y_test))
print("The Cross val score of XGB is:")
print(cross_val_score(xgb,X,Y,cv=10))
# Out:
# The first 10 predicted values of Y is:
# [ 8  8 10  6  9  8  5  5 10  8]
# The first 10 test values of Y is:
# [ 6  8 10  1  9 10  5  5  8  8]
# The accuracy of XGB is:
# 0.5145693243675953
# The Cross val score of XGB is:
# [0.51600512 0.50640205 0.50960307 0.5214606  0.49839846 0.52914798
#  0.50288277 0.49903908 0.49519539 0.52338245]

# %%
from sklearn.model_selection import cross_val_score
models = [lr,nb,knn,lasso,ridge,lrr,svc,rfc,xgb]
accuracies =[]

for i in models:
    scores = cross_val_score(i,X,Y,cv=5)
    accuracies.append (np.mean(scores))

# %%
accuracies
# Out:
# [0.12066855110253608,
#  0.2530578955541155,
#  0.4345095377377204,
#  -0.00019287980980884357,
#  0.12066940495681452,
#  0.49522716191149,
#  0.5228325808209758,
#  0.5021450858594344,
#  0.5100237681905015]

# %%
from sklearn import metrics

for i in models:
    Y_predict = i.predict(X_test)

    if Y_predict.dtype.kind in 'fc':  # 'f' for floating point, 'c' for complex numbers
        Y_predict = Y_predict.round().astype(int)  # Round and convert to integer

    # Compute the confusion matrix
    matrix = metrics.confusion_matrix(Y_test, Y_predict)
    
    # Plot the confusion matrix
    sns.heatmap(matrix, annot=True, fmt='d', cmap='Blues')
    plt.show()
